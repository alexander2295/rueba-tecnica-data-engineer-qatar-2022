# %%
import json
import pandas as pd

# 1) Cargar el JSON (ajusta el nombre si lo renombraste)
with open("CENTROS_EDUCATIVOS_MADRID.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# 2) Pasar a DataFrame
df = pd.DataFrame(data)

# 3) Exploración básica
print("Filas y columnas:", df.shape)
print("\nColumnas:")
print(df.columns.tolist())

print("\nPrimeras filas:")
print(df.head())
